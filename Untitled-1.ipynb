# %%
import json
tt = {'a':1, 'b':2}
with open("kartik.json", "w") as fp:
    json.dump(tt,fp)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In [2], line 3
#       1 import json
#       2 tt = {'a':1, 'b':2}
# ----> 3 with open("kartik.json", "w") as fp:
#       4     json.dump(tt,fp)
#
# File ~/opt/miniconda3/envs/kartik_env/lib/python3.10/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# OSError: [Errno 30] Read-only file system: 'kartik.json'

# %%
import os
os.getcwd()
# Out:
# '/'
